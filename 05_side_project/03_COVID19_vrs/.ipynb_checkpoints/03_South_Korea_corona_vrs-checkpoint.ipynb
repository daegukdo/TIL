# %% [markdown]
# ### 한국에서 코로나 바이러스가 발생한 위치와 도시
#
#  - csv 파일 형식
#
#  - column 항목
#
#  > 0. 환자 id
#  >
#  > 1. 날짜
#  >
#  > 2. 지역
#  >
#  > 3. 도시 이름
#  >
#  > 4. 방문지
#  >
#  > 5. 위도
#  >
#  > 6. 경도

# %%
# draw charts
# %matplotlib notebook

from matplotlib import pyplot as plt
import numpy as np

# %%
# CSV 파일 읽어들이기

import csv  # csv 모듈 임포트
import pprint

# 파일 위치, 경로 정의
file_path = '01_South_Korea/route.csv'

# route.csv 파일 열기
with open(file_path) as file:
    reader = csv.reader(file)  # CSV 파일을 읽어들이는 읽기 객체
    raw = list(reader)      #  CSV 파일 내용을 리스트로 읽어들인다

pprint.pprint(raw[:10])  # 읽어들인 내용을 화면에 출력
# Out:
# [['patient_id', 'date', 'province', 'city', 'visit', 'latitude', 'longitude'],
#  ['1', '2020-01-19', 'Incheon', 'Jung-gu', 'airport', '37.460459', '126.44068'],
#  ['1',
#   '2020-01-20',
#   'Incheon',
#   'Seo-gu',
#   'hospital_isolated',
#   '37.478832',
#   '126.668558'],
#  ['2',
#   '2020-01-22',
#   'Gyeonggi-do',
#   'Gimpo-si',
#   'airport',
#   '37.562143',
#   '126.801884'],
#  ['2',
#   '2020-01-23',
#   'Seoul',
#   'Jung-gu',
#   'hospital_isolated',
#   '37.567454',
#   '127.005627'],
#  ['3', '2020-01-20', 'Incheon', 'Jung-gu', 'airport', '37.460459', '126.44068'],
#  ['3',
#   '2020-01-22',
#   'Seoul',
#   'Gangnam-gu',
#   'clinic',
#   '37.524978',
#   '127.027718'],
#  ['3', '2020-01-22', 'Seoul', 'Gangnam-gu', 'hotel', '37.503359', '127.049177'],
#  ['3', '2020-01-23', 'Seoul', 'Gangnam-gu', 'store', '37.524669', '127.015911'],
#  ['3',
#   '2020-01-23',
#   'Seoul',
#   'Gangnam-gu',
#   'restaurant',
#   '37.5292',
#   '127.032597']]

# %%
# 안내를 위한 row를 삭제
raw_ = raw[1:]

# %%
city_of_patient = []
latitude_city = []
longitude_city = []

for i in range(len(raw_)):
    city_name = raw_[i][3]
    latitude_value = raw_[i][5]
    longitude_value = raw_[i][6]
    
    city_of_patient.append(city_name)
    latitude_city.append(latitude_value)
    longitude_city.append(longitude_value)

# %%
import folium
southkorea_map = folium.Map(location=[36.55,126.983333], zoom_start=7, titles='loation of patient in South Korea')

for lat, lon,city in zip(latitude_city, longitude_city, city_of_patient):
    folium.CircleMarker([lat, lon],
                        radius=5,
                        color='red',
                        popup =('City: ' + str(city) + '<br>'),
                        fill_color='red',
                        fill_opacity=0.7 ).add_to(southkorea_map)
southkorea_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
southkorea_map.save('COVID_19_in_South_Korea.html')
